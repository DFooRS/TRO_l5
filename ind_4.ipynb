# %%
import matplotlib.pyplot as plt
import requests
from io import BytesIO
from PIL import Image
# %matplotlib inline

response = requests.get('https://cdnn1.ukraina.ru/img/07e6/0c/02/1041436899_0:206:2905:1840_1920x0_80_0_0_c7022893b761781d76fe592010d14bd2.jpg')
img = Image.open(BytesIO(response.content))
plt.imshow(img)
